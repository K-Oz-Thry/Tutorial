# %% [markdown]
# # Tutorial #2
# # Bokeh & Plotly

# %% [markdown]
# Now that we have learned from the previous libraries, let's try to make **interactive** multivariable graphics

# %% [markdown]
# # Gallery

# %% [markdown]
# https://docs.bokeh.org/en/latest/docs/gallery.html
